# %%
from collections import defaultdict

metrics = defaultdict()
# Model: bert_classifier
model_name = "bert_classifier"
train_loss = [0.6022, 0.5378, 0.4308]
eval_loss = [0.5429, 0.5422, 0.5973]
train_accuracy =  0.82 
test_accuracy = 0.56

metrics[model_name] = {
    "train_loss": train_loss,
    "eval_loss": eval_loss,
    "train_accuracy": train_accuracy,
    "test_accuracy": test_accuracy
}

# Model: Fine-tuned ResNet18
model_name = "resnet18"
train_loss = [0.8378587017180034, 0.7185671639743066, 0.7006370623087, 0.6910241164957159, 0.6741008267575718, 0.6755293594577136, 0.6686075033162131, 0.6393027293802909, 0.6390367304972537, 0.6346590471750944, 0.6341406968357483, 0.6331265978365891, 0.6337438616484593, 0.634378069601277, 0.6288583653520475, 0.6295346915511177, 0.6278542980618447, 0.6296825431131007, 0.6303081947018621, 0.6261240330867376]
eval_loss = [0.7174013494995723, 0.6571713373075531, 0.6615399996570729, 0.6978588148077057, 0.6711742162016128, 0.637704769536175, 0.6457576219298888, 0.6302652476658778, 0.6385800142895633, 0.6354402702722295, 0.6421354471084899, 0.6271654008807592, 0.623437797702935, 0.6173080711566472, 0.6168943388743584, 0.6219512342620003, 0.6253251989734024, 0.6217427474272973, 0.6220892845193592, 0.6175460426798413]
train_accuracy = 0.6626
test_accuracy = 0.6700

metrics[model_name] = {
    "train_loss": train_loss,
    "eval_loss": eval_loss,
    "train_accuracy": train_accuracy,
    "test_accuracy": test_accuracy
}

# Model: Multimodal NeuralNetwork Classifier with 2 Layers
model_name = "multimodal_classifier_2layer"
train_loss = []
eval_loss = []
train_accuracy = 0.635225355
test_accuracy = 0.63570636

metrics[model_name] = {
    "train_loss": train_loss,
    "eval_loss": eval_loss,
    "train_accuracy": train_accuracy,
    "test_accuracy": test_accuracy
}

# Model: Multimodal NeuralNetwork Classifier with 4 Layers
train_loss = []
eval_loss = []
train_accuracy = 0.635225355
test_accuracy = 0.6351501941
